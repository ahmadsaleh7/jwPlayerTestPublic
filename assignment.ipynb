# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadsaleh7/jwPlayerTestPublic/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = pd.read_csv(io.BytesIO(uploaded['tested.csv']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ceba0377ad8b> in <cell line: 1>()
# ----> 1 data = pd.read_csv(io.BytesIO(uploaded['tested.csv']))
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import io

data = pd.read_csv(io.BytesIO(uploaded['tested.csv']))
# Now you can use pd to refer to pandas functions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3cce9fca5015> in <cell line: 4>()
#       2 import io
#       3
# ----> 4 data = pd.read_csv(io.BytesIO(uploaded['tested.csv']))
#       5 # Now you can use pd to refer to pandas functions
#
# NameError: name 'uploaded' is not defined

# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your file
data = pd.read_csv('tested.csv')

# Now you can use the 'data' DataFrame
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e3450b6b0996> in <cell line: 4>()
#       2
#       3 # Replace 'your_file.csv' with the actual path to your file
# ----> 4 data = pd.read_csv('your_file.csv')
#       5
#       6 # Now you can use the 'data' DataFrame
#
# ...

# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your file
data = pd.read_csv('tested.csv')

# Now you can use the 'data' DataFrame
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-0a363548e669> in <cell line: 4>()
#       2
#       3 # Replace 'your_file.csv' with the actual path to your file
# ----> 4 data = pd.read_csv('tested.csv')
#       5
#       6 # Now you can use the 'data' DataFrame
#
# ...

# %%
import pandas as pd

# Update the file path to the correct location of 'tested.csv'
file_path = '/tested.csv'  # Replace with the actual file path
data = pd.read_csv(file_path)

print(data.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(data.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       0
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mean(), inplace=True)

# %%
data['Age'].fillna(data['Age'].mean(), inplace=True)

# %%
print(data.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8e0a8f568d89> in <cell line: 1>()
# ----> 1 plt.figure(figsize=(10, 6))
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))

# %%
sns.histplot(data['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.title('Distribution of Passenger Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], kde=True)
plt.title('Distribution of Passenger Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
